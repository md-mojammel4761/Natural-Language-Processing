# %%
import nltk 
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download("stopword")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Error loading stopword: Package 'stopword' not found in
# [nltk_data]     index

# %%
sen = "I love machine learning and deep learning"

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\h\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\h\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
word = word_tokenize(sen)
print(word)
# Out:
# ['I', 'love', 'machine', 'learning', 'and', 'deep', 'learning']

# %%
for idx, words in enumerate(word):
    print(f"index number is :{idx} and the actual word is '{words}'")
# Out:
# index number is :0 and the actual word is 'I'
# index number is :1 and the actual word is 'love'
# index number is :2 and the actual word is 'machine'
# index number is :3 and the actual word is 'learning'
# index number is :4 and the actual word is 'and'
# index number is :5 and the actual word is 'deep'
# index number is :6 and the actual word is 'learning'

# %%
para = "Cows are gentle, domesticated mammals vital to humans, providing essential products like milk, meat, and leather. while also serving as farm labor, known for their calm nature and herbivorous diet of grass and hay, giving us nutritious dairy. enriching soil with their dung. These social herd animals, with breeds varying in color and size, are easily recognized by their large bodies, four legs, horns, and tails, and are valued globally for their multi-faceted contributions to agriculture. sustenance, often treated with reverence as Gau Mata (Mother Cow) in some cultures."

# %%
stop_word = stopwords.words("english")
stop_word
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
from nltk import pos_tag
sen = "I love machine learning and deep learning"
word = word_tokenize(sen)
text = pos_tag(word)

# %%
text
# Out:
# [('I', 'PRP'),
#  ('love', 'VBP'),
#  ('machine', 'NN'),
#  ('learning', 'NN'),
#  ('and', 'CC'),
#  ('deep', 'JJ'),
#  ('learning', 'NN')]

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
para
# Out:
# 'Cows are gentle, domesticated mammals vital to humans, providing essential products like milk, meat, and leather. while also serving as farm labor, known for their calm nature and herbivorous diet of grass and hay, giving us nutritious dairy. enriching soil with their dung. These social herd animals, with breeds varying in color and size, are easily recognized by their large bodies, four legs, horns, and tails, and are valued globally for their multi-faceted contributions to agriculture. sustenance, often treated with reverence as Gau Mata (Mother Cow) in some cultures.'

# %%
port_stem = PorterStemmer()
token = word_tokenize(para)
stem_word = [port_stem.stem(tokens) for tokens in token]
stem_sen = " ".join(stem_word)

# %%
stem_sen
# Out:
# 'cow are gentl , domest mammal vital to human , provid essenti product like milk , meat , and leather . while also serv as farm labor , known for their calm natur and herbivor diet of grass and hay , give us nutriti dairi . enrich soil with their dung . these social herd anim , with breed vari in color and size , are easili recogn by their larg bodi , four leg , horn , and tail , and are valu global for their multi-facet contribut to agricultur . susten , often treat with rever as gau mata ( mother cow ) in some cultur .'

# %%
nltk.download('wordnet')

# %%
wnl_stem = WordNetLemmatizer()
token = word_tokenize(para)
lemma_word = [wnl_stem.lemmatize(tokens) for tokens in token]
lemma_sen = " ".join(stem_word1)

# %%
lemma_sen
# Out:
# 'Cows are gentle , domesticated mammal vital to human , providing essential product like milk , meat , and leather . while also serving a farm labor , known for their calm nature and herbivorous diet of grass and hay , giving u nutritious dairy . enriching soil with their dung . These social herd animal , with breed varying in color and size , are easily recognized by their large body , four leg , horn , and tail , and are valued globally for their multi-faceted contribution to agriculture . sustenance , often treated with reverence a Gau Mata ( Mother Cow ) in some culture .'

# %%
pip install spacy

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy

# %%
text = "I love machine learning and deep learning. I usually wake up in the morning to start a healthy day"

# %%
nlp = spacy.load("en_core_web_sm")
lemma_token = nlp(para)
lemma_word = [words.lemma_ for words in lemma_token]
lemma_sen = " ".join(lemma_word)

# %%
lemma_sen
# Out:
# 'cow be gentle , domesticate mammal vital to human , provide essential product like milk , meat , and leather . while also serve as farm labor , know for their calm nature and herbivorous diet of grass and hay , give we nutritious dairy . enrich soil with their dung . these social herd animal , with breed vary in color and size , be easily recognize by their large body , four leg , horn , and tail , and be value globally for their multi - faceted contribution to agriculture . sustenance , often treat with reverence as Gau Mata ( Mother Cow ) in some culture .'

# %%
stem_sen
# Out:
# 'cow are gentl , domest mammal vital to human , provid essenti product like milk , meat , and leather . while also serv as farm labor , known for their calm natur and herbivor diet of grass and hay , give us nutriti dairi . enrich soil with their dung . these social herd anim , with breed vari in color and size , are easili recogn by their larg bodi , four leg , horn , and tail , and are valu global for their multi-facet contribut to agricultur . susten , often treat with rever as gau mata ( mother cow ) in some cultur .'

# %%
text = ["change","changes","changing","changed"]
token = [port_stem.stem(tokens) for tokens in text]
token
# Out:
# ['chang', 'chang', 'chang', 'chang']

# %%
text = ["change","changes","changing","changed"]
token = [wnl_stem.lemmatize(tokens) for tokens in text]
token
# Out:
# ['change', 'change', 'changing', 'changed']

# %%
text = "Cows ,are gene4tle, domestic3ated mamm4als vital to human5s, pro23viding essenti54al prod6uctsd like milk, meat, and leather. while also serving as farm labor, known for their calm nature and herbivorous diet of grass and hay, giving us nutritious dairy. enriching soil with their dung. These social herd animals, with breeds varying in color and size, are easily recognized by their large bodies, four legs, horns, and tails, and are valued globally for their multi-faceted contributions to agriculture. sustenance, often treated with reverence as Gau Mata (Mother Cow) in some cultures."

# %%
lemma_token = nlp(para)
type(lemma_token)
# Out:
# spacy.tokens.doc.Doc

# %%
token = word_tokenize(text)
stop_rem = [words.lower() for words in token if token not in stop_word]
lemma_word = [wnl_stem.lemmatize(tokens) for tokens in stop_rem]
lemma_sen = " ".join(lemma_word)
lemma_sen

import re
clean_pun = re.sub(r'[^\w\s]', '', lemma_sen).strip()
clean_num = re.sub(r'\d+', '', clean_pun)
clean_num
# Out:
# 'cow  are genetle  domesticated mammals vital to humans  providing essential productsd like milk  meat  and leather  while also serving a farm labor  known for their calm nature and herbivorous diet of grass and hay  giving u nutritious dairy  enriching soil with their dung  these social herd animal  with breed varying in color and size  are easily recognized by their large body  four leg  horn  and tail  and are valued globally for their multifaceted contribution to agriculture  sustenance  often treated with reverence a gau mata  mother cow  in some culture'

# %%
from sklearn.feature_extraction.text import CountVectorizer
cvt = CountVectorizer(stop_words=None)

# %%
trans_form_data = cvt.fit_transform([clean_num])
trans_form_data
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 70 stored elements and shape (1, 70)>

# %%
data = trans_form_data.toarray()

# %%
data.shape
# Out:
# (1, 70)
